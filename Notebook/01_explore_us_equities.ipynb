# %%
import polars as pl
import pandas as pd
import numpy as np

from pathlib import Path

# base paths
BASE_DIR = Path("..").resolve()
DATA_RAW = BASE_DIR / "data" / "raw"
DATA_CLEAN = BASE_DIR / "data" / "clean"

BASE_DIR, DATA_RAW, DATA_CLEAN
# Out:
# (PosixPath('/Users/Admin/Documents/EPFL/Master/MA3/Financial Big Data/Project'),
#  PosixPath('/Users/Admin/Documents/EPFL/Master/MA3/Financial Big Data/Project/data/raw'),
#  PosixPath('/Users/Admin/Documents/EPFL/Master/MA3/Financial Big Data/Project/data/clean'))
